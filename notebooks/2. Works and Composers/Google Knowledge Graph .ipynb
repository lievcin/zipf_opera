# %%
"""Example of Python client calling Knowledge Graph Search API."""
import json
import urllib
from urllib import request

api_key = 'AIzaSyCJ1ErcwXdwA7vh93kXiiYDLg1JkuEQ_Nc'
query = 'A Christmas Eve'#'Robert J. Bradshaw.'#'.Gabriel'
service_url = 'https://kgsearch.googleapis.com/v1/entities:search'
params = {
    'query': query,
    'limit': 5,
    'indent': True,
    'key': api_key,
#     'types': 'Thing',
    'types': 'MusicComposition'
}
url = service_url + '?' + urllib.parse.urlencode(params)
print(url)
response = json.loads(urllib.request.urlopen(url).read())
for element in response['itemListElement']:
#     print(element['result']['name'] + ' (' + str(element['resultScore']) + ')')
#     print(element['result']['detailedDescription']['url'])
    print(element)
# Out:
# https://kgsearch.googleapis.com/v1/entities:search?query=A+Christmas+Eve&limit=5&indent=True&key=AIzaSyCJ1ErcwXdwA7vh93kXiiYDLg1JkuEQ_Nc&types=MusicComposition
# ...

# %%
from bs4 import BeautifulSoup
import requests, urllib
from datetime import datetime

headers = { 'User-Agent': 'Mozilla/5.0 (Windows NT 6.0; WOW64; rv:24.0) Gecko/20100101 Firefox/24.0' }
base_url = 'http://operadata.stanford.edu/?utf8=%E2%9C%93&utf8=%E2%9C%93&search_field=title&'

#################### UPDATE COMPOSER ATTRIBUTES ####################
import psycopg2
import pandas as pd

db_name = "traviato_development"
db_host = "localhost"
db_port = "5432"
db_user = "lievgarcia"
db_pwd = "traviato81"

conn = psycopg2.connect(database=db_name, user=db_user, password=db_pwd, host=db_host, port=db_port)
#######################################################################

cursor = conn.cursor()  
query = "select id, name, uri from works c WHERE premiere_date IS NULL ORDER BY name"
cursor.execute(query)
c_df = pd.DataFrame(cursor.fetchall(), columns=['id', 'name', 'uri'])
print(c_df.shape)

api_key = 'AIzaSyCJ1ErcwXdwA7vh93kXiiYDLg1JkuEQ_Nc'
service_url = 'https://kgsearch.googleapis.com/v1/entities:search'
    
for idx,row in c_df.iterrows():
    
    if idx%250==0:
        print(idx)
        
    query = row['name']
    params = {
        'query': query,
        'limit': 5,
        'indent': True,
        'key': api_key,
        'types': 'MusicComposition'
    }
    url = service_url + '?' + urllib.parse.urlencode(params)
    response = json.loads(urllib.request.urlopen(url).read())
    for element in response['itemListElement']:   
        try:
            if element['result']['name'].lower()==row['name'].lower():
                premiere = 'Unknown'
    #             print(element['result']['detailedDescription']['articleBody'])
                if bool(re.search(r'(?:(?<!\d)\d{4}(?!\d))', element['result']['detailedDescription']['articleBody'])):
#                     print('------------------------------------------------')                        
#                     print(row['name'])        
                    premiere = re.search(r'(?:(?<!\d)\d{4}(?!\d))', element['result']['detailedDescription']['articleBody'][4:]).group(0)
#                     print('Premiered on: ' + str(premiere))
                    
                    update = "UPDATE WORKS "
                    values = "SET premiere_date = '" + str(premiere) + "' "
                    where  = "WHERE id = " + str(row['id']) + "; "
                    commit = "COMMIT;"
                    print(update + values + where + commit)    
                    cursor.execute(update + values + where + commit)                       
#                 print('------------------------------------------------')        
        except:
            None
# Out:
# (6097, 3)
# 0
# UPDATE WORKS SET premiere_date = '1985' WHERE id = 12340; COMMIT;
# UPDATE WORKS SET premiere_date = '1930' WHERE id = 5318; COMMIT;
# UPDATE WORKS SET premiere_date = '1993' WHERE id = 5347; COMMIT;
# UPDATE WORKS SET premiere_date = '1871' WHERE id = 12477; COMMIT;
# UPDATE WORKS SET premiere_date = '2009' WHERE id = 12507; COMMIT;
# UPDATE WORKS SET premiere_date = '1908' WHERE id = 5396; COMMIT;
# UPDATE WORKS SET premiere_date = '1672' WHERE id = 5433; COMMIT;
# UPDATE WORKS SET premiere_date = '1734' WHERE id = 5436; COMMIT;
# UPDATE WORKS SET premiere_date = '1869' WHERE id = 5480; COMMIT;
# UPDATE WORKS SET premiere_date = '1778' WHERE id = 3891; COMMIT;
# UPDATE WORKS SET premiere_date = '1798' WHERE id = 12724; COMMIT;
# UPDATE WORKS SET premiere_date = '1810' WHERE id = 5572; COMMIT;
# UPDATE WORKS SET premiere_date = '1970' WHERE id = 12754; COMMIT;
# 250
# UPDATE WORKS SET premiere_date = '1744' WHERE id = 698; COMMIT;
# ...

# %%
from bs4 import BeautifulSoup
import requests, urllib, json
from datetime import datetime

headers = { 'User-Agent': 'Mozilla/5.0 (Windows NT 6.0; WOW64; rv:24.0) Gecko/20100101 Firefox/24.0' }
base_url = 'http://operadata.stanford.edu/?utf8=%E2%9C%93&utf8=%E2%9C%93&search_field=title&'

########## UPDATE OPERA HOUSES CITY AND STATES ATTRIBUTES #############
import psycopg2
import pandas as pd

db_name = "traviato_development"
db_host = "localhost"
db_port = "5432"
db_user = "lievgarcia"
db_pwd = "traviato81"

conn = psycopg2.connect(database=db_name, user=db_user, password=db_pwd, host=db_host, port=db_port)
#######################################################################

cursor = conn.cursor()  
query = "select state, city, theatre, count(*) as count from listings where source_id = 1 and city is null " + \
        "group by state, city, theatre order by state, city, theatre"
cursor.execute(query)
c_df = pd.DataFrame(cursor.fetchall(), columns=['state', 'city', 'theatre', 'count'])
print(c_df.shape)

api_key = 'AIzaSyAiEcfaF5AfGTdh4vHBPLW6IwNgbFBjOUs'
service_url = 'https://maps.googleapis.com/maps/api/geocode/json'
    
for idx,row in c_df.iterrows():
    
    state, city = None,None
    
    if idx%250==0:
        print(idx)
        
    query = row['theatre']
    params = {
        'address': query,
        'key': api_key
    }
    url = service_url + '?' + urllib.parse.urlencode(params)
#     print(url)
    response = json.loads(urllib.request.urlopen(url).read())
    try:
        for items in response['results'][0]['address_components']:
            if 'administrative_area_level_1' in items['types']:
                state = items['long_name']
            if 'locality' in items['types']:
                city = items['long_name'] 

        if state and city:
            update = "UPDATE LISTINGS "
            values = "SET city = '" + city + "', state = '" + state + "' "
            where  = "WHERE source_id = 1 AND theatre = '" + row['theatre'].replace("'", "''") + "'; "
            commit = "COMMIT;"
#             print(update + values + where + commit)    
            cursor.execute(update + values + where + commit)
    except:
        None
# Out:
# (187, 4)
# 0

# %%
from bs4 import BeautifulSoup
import requests, urllib, json
from datetime import datetime

headers = { 'User-Agent': 'Mozilla/5.0 (Windows NT 6.0; WOW64; rv:24.0) Gecko/20100101 Firefox/24.0' }
base_url = 'http://operadata.stanford.edu/?utf8=%E2%9C%93&utf8=%E2%9C%93&search_field=title&'

########## UPDATE OPERA HOUSES CITY AND STATES ATTRIBUTES #############
import psycopg2
import pandas as pd

db_name = "traviato_development"
db_host = "localhost"
db_port = "5432"
db_user = "lievgarcia"
db_pwd = "traviato81"

conn = psycopg2.connect(database=db_name, user=db_user, password=db_pwd, host=db_host, port=db_port)
#######################################################################

cursor = conn.cursor()  
# query = "select state, city, theatre, count(*) as count from listings where source_id = 11 and state is null " + \
#         "group by state, city, theatre order by state, city, theatre"
    
query = "select state, city, count(*) as count from listings where source_id = 11 and state is null " + \
        "group by state, city order by state, city"
    
cursor.execute(query)
c_df = pd.DataFrame(cursor.fetchall(), columns=['state', 'city', 'count'])
print(c_df.shape)

api_key = 'AIzaSyAiEcfaF5AfGTdh4vHBPLW6IwNgbFBjOUs'
service_url = 'https://maps.googleapis.com/maps/api/geocode/json'
    
for idx,row in c_df.iterrows():
    
    state, city = None,None
    
    if idx%250==0:
        print(idx)
        
    query = row['city'] + ' United Kingdom'
    params = {
        'address': query,
        'key': api_key
    }
    url = service_url + '?' + urllib.parse.urlencode(params)
#     print(url)
    response = json.loads(urllib.request.urlopen(url).read())
    try:
        for items in response['results'][0]['address_components']:
            if 'administrative_area_level_1' in items['types']:
                state = items['long_name']
#             if 'locality' in items['types']:
#                 city = items['long_name'] 

#         if state and city:
#             update = "UPDATE LISTINGS "
#             values = "SET city = '" + city + "', state = '" + state + "' "
#             where  = "WHERE source_id = 7 AND theatre = '" + row['theatre'].replace("'", "''") + "' and city IS NULL; "
#             commit = "COMMIT;"
#             print(update + values + where + commit)    
#             cursor.execute(update + values + where + commit)

#         if city:
#             update = "UPDATE LISTINGS "
#             values = "SET city = '" + city + "' "
#             where  = "WHERE source_id = 7 AND theatre = '" + row['theatre'].replace("'", "''") + "' and city IS NULL; "
#             commit = "COMMIT;"
#             print(update + values + where + commit)   
#             cursor.execute(update + values + where + commit)

        if state:
            update = "UPDATE LISTINGS "
            values = "SET state = '" + state + "' "
            where  = "WHERE source_id = 11 AND city = '" + row['city'].replace("'", "''") + "'; "
            commit = "COMMIT;"
#             print(update + values + where + commit)   
            cursor.execute(update + values + where + commit)


    except:
        None
# Out:
# (4, 3)
# 0
