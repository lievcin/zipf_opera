# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd

# %%
# stri = "√Åbr√°nyi, Emil"
# stri = stri.encode(encoding='mac_roman')
# stri = codecs.decode(stri, encoding='utf-8', errors='strict')

df = pd.read_csv('../../data/processed/composers_masterlist.csv')

def fix_encoding(string):
    try:
        string = string.encode(encoding='mac_roman')        
        string = codecs.decode(string, encoding='utf-8', errors='strict')
    except:
        None
        
    return string

df['clean_name'] = df.apply(lambda row: fix_encoding(row['clean_name']), axis=1)
df['other_names'] = df.apply(lambda row: fix_encoding(row['other_names']), axis=1)
df['stanford_name'] = df.apply(lambda row: fix_encoding(row['stanford_name']), axis=1)
    
df.head(100)
# Out:
#                           clean_name  \
# 0                      Ábrányi, Emil
# 1                         Ádám, Jenö
# 2                    Ásgeirsson, Jón
# 3                Ölander, Per August
# 4                     Åhlström, Olof
# 5                     Åkerberg, Erik
# 6                         Aav, Evald
# 7             Abbà Cornaglia, Pietro
# 8                    Abbadia, Natale
# 9            Abbatini, Antonio Maria
# 10                       Abdullaev,
# 11                   Abeille, Ludwig
# 12              Abert, Johann Joseph
# 13                    Abos, Girolamo
# 14                Aboulker, Isabelle
# 15                         Abraham,
# 16               Abramsky, Alexander
# 17                       Absil, Jean
# 18                        Abt, Franz
# 19               Acciaiuoli, Filippo
# 20             Accorimboni, Agostino
# 21           Aceves y Lozano, Rafael
# 22                      Acton, Carlo
# 23                             Ada,
# ...

# %%
ifile
